# %% [markdown]
# <a href="https://colab.research.google.com/github/sydneysimmons/bottle-image-classification-project/blob/main/Base_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision import transforms
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/sydneysimmons/bottle-image-classification-project.git
# Out:
# Cloning into 'bottle-image-classification-project'...
# remote: Enumerating objects: 40023, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 40023 (delta 0), reused 7 (delta 0), pack-reused 40016
# Receiving objects: 100% (40023/40023), 1.24 GiB | 16.98 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Checking out files: 100% (40006/40006), done.

# %%
pwd
# Out:
# '/content'

# %%
cd '../content'
# Out:
# /content

# %%
data_dir = "/content/bottle-image-classification-project/data/Bottle Images"

# %%
#load the train and test data
dataset = ImageFolder(data_dir,transform = transforms.Compose([
    transforms.Resize((150,150)),transforms.ToTensor()
]))

# %%
img, label = dataset[0]
print(img.shape,label)
# Out:
# torch.Size([3, 150, 150]) 0

# %%
print("Follwing classes are there : \n",dataset.classes)
# Out:
# Follwing classes are there :
#  ['Beer Bottles', 'Plastic Bottles', 'Soda Bottle', 'Water Bottle', 'Wine Bottle']

# %%
def display_img(img,label):
    print(f"Label : {dataset.classes[label]}")
    plt.imshow(img.permute(1,2,0))

#display the first image in the dataset
display_img(*dataset[0])
# Out:
# Label : Beer Bottles
